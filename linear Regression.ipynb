# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=sb.load_dataset("tips")
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.all()
# Out:
# total_bill    True
# tip           True
# sex           True
# smoker        True
# day           True
# time          True
# size          True
# dtype: bool
# total_bill    True
# tip           True
# sex           True
# smoker        True
# day           True
# time          True
# size          True
# dtype: bool

# %%
#a=sb.load_dataset("tips")

# %%
sb.relplot(x="tip",y="total_bill",data=df)

# %%
sb.relplot(x="tip",y="total_bill",data=df,kind="line")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.sample(5)   #random line checking
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 194       16.58  4.00    Male    Yes  Thur   Lunch     2
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2
#      total_bill   tip     sex smoker   day    time  size
# 194       16.58  4.00    Male    Yes  Thur   Lunch     2
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2

# %% [raw]
# # analyze the data

# %%
df.groupby('day').count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
df2=df.groupby('day').sum()  #sum per day
df2.drop('size',inplace=True,axis=1)
df2['percent']=df2['tip']/df2['total_bill']*100  #add percentage
print(df2)
# Out:
#       total_bill     tip    percent
# day
# Thur     1096.33  171.83  15.673201
# Fri       325.88   51.96  15.944519
# Sat      1778.40  260.40  14.642375
# Sun      1627.16  247.39  15.203791
#       total_bill     tip    percent
# day
# Thur     1096.33  171.83  15.673201
# Fri       325.88   51.96  15.944519
# Sat      1778.40  260.40  14.642375
# Sun      1627.16  247.39  15.203791

# %%
df.groupby('size').count()
# Out:
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4
#       total_bill  tip  sex  smoker  day  time
# size
# 1              4    4    4       4    4     4
# 2            156  156  156     156  156   156
# 3             38   38   38      38   38    38
# 4             37   37   37      37   37    37
# 5              5    5    5       5    5     5
# 6              4    4    4       4    4     4

# %%
df2=df.groupby('day').sum()
df2.drop('size',inplace=True,axis=1)
df2
# Out:
#       total_bill     tip
# day
# Thur     1096.33  171.83
# Fri       325.88   51.96
# Sat      1778.40  260.40
# Sun      1627.16  247.39
#       total_bill     tip
# day
# Thur     1096.33  171.83
# Fri       325.88   51.96
# Sat      1778.40  260.40
# Sun      1627.16  247.39

# %%
df2['percent']=df2['tip']/df2['total_bill']*100  #add percentage
print(df2)
# Out:
#       total_bill     tip    percent
# day
# Thur     1096.33  171.83  15.673201
# Fri       325.88   51.96  15.944519
# Sat      1778.40  260.40  14.642375
# Sun      1627.16  247.39  15.203791
#       total_bill     tip    percent
# day
# Thur     1096.33  171.83  15.673201
# Fri       325.88   51.96  15.944519
# Sat      1778.40  260.40  14.642375
# Sun      1627.16  247.39  15.203791

# %%
df2=df.groupby('day').sum()
df2.drop('size',axis=1)
df2
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
df2
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
# !python --version
# Out:
# Python 3.7.3
# Python 3.7.3

# %%
df2['percent']=df2['tip']/df2['total_bill']*100  #add percentage
print(df2)
# Out:
#       total_bill     tip  size    percent
# day
# Thur     1096.33  171.83   152  15.673201
# Fri       325.88   51.96    40  15.944519
# Sat      1778.40  260.40   219  14.642375
# Sun      1627.16  247.39   216  15.203791
#       total_bill     tip  size    percent
# day
# Thur     1096.33  171.83   152  15.673201
# Fri       325.88   51.96    40  15.944519
# Sat      1778.40  260.40   219  14.642375
# Sun      1627.16  247.39   216  15.203791

# %%
df3=df.groupby('smoker').sum()  #sum per day
#df2.drop('size',inplace=True,axis=1)
df3['percent']=df3['tip']/df3['total_bill']*100  #add percentage
print(df3)
# Out:
#         total_bill     tip  size    percent
# smoker
# Yes        1930.34  279.81   224  14.495374
# No         2897.43  451.77   403  15.592094
#         total_bill     tip  size    percent
# smoker
# Yes        1930.34  279.81   224  14.495374
# No         2897.43  451.77   403  15.592094

# %%
df4=df.groupby(['day','size']).sum()  #sum per day
#df4.drop('size',inplace=True,axis=1)
df4['percent']=df4['tip']/df4['total_bill']*100  #add percentage
#df4.dropna()
print(df4)
# Out:
#            total_bill     tip    percent
# day  size
# Thur 1          10.07    1.83  18.172790
#      2         727.53  117.24  16.114799
#      3          76.64   10.77  14.052714
#      4         149.75   21.09  14.083472
#      5          41.19    5.00  12.138869
#      6          91.15   15.90  17.443774
# Fri  1           8.58    1.92  22.377622
#      2         261.15   42.31  16.201417
#      3          15.98    3.00  18.773467
#      4          40.17    4.73  11.774956
#      5            NaN     NaN        NaN
#      6            NaN     NaN        NaN
# Sat  1          10.32    2.00  19.379845
#      2         892.37  133.43  14.952318
#      3         459.17   68.36  14.887732
#      4         388.39   53.61  13.803136
#      5          28.15    3.00  10.657194
#      6            NaN     NaN        NaN
# Sun  1            NaN     NaN        NaN
#      2         684.84  109.86  16.041703
#      3         332.76   46.81  14.067196
# ...

# %%
df3=df.groupby('sex').sum()  #sum per day
#df2.drop('size',inplace=True,axis=1)
df3['percent']=df3['tip']/df3['total_bill']*100  #add percentage
print(df3)
# Out:
#         total_bill     tip  size    percent
# sex
# Male       3256.82  485.07   413  14.893976
# Female     1570.95  246.51   214  15.691779
#         total_bill     tip  size    percent
# sex
# Male       3256.82  485.07   413  14.893976
# Female     1570.95  246.51   214  15.691779

# %%
df5=df.groupby(['smoker','sex','day','size']).sum()  #sum per day
#df4.drop('size',inplace=True,axis=1)
df5['percent']=df5['tip']/df5['total_bill']*100  #add percentage
#df4.dropna()
print(df5)
# Out:
#                          total_bill    tip    percent
# smoker sex    day  size
# Yes    Male   Thur 1            NaN    NaN        NaN
#                    2         152.47  22.58  14.809471
#                    3          18.71   4.00  21.378942
#                    4          20.53   4.00  19.483682
#                    5            NaN    NaN        NaN
#                    6            NaN    NaN        NaN
#               Fri  1           8.58   1.92  22.377622
#                    2         114.87  15.28  13.301994
#                    3            NaN    NaN        NaN
#                    4          40.17   4.73  11.774956
#                    5            NaN    NaN        NaN
#                    6            NaN    NaN        NaN
#               Sat  1            NaN    NaN        NaN
#                    2         293.39  39.41  13.432632
#                    3         123.15  18.41  14.949249
#                    4         144.93  16.92  11.674602
# ...

# %%
df6=df.groupby(['smoker','sex']).sum()  #sum per day
#df4.drop('size',inplace=True,axis=1)
df6['percent']=df6['tip']/df6['total_bill']*100  #add percentage
#df4.dropna()
print(df6)
# Out:
#                total_bill     tip  size    percent
# smoker sex
# Yes    Male       1337.07  183.07   150  13.691879
#        Female      593.27   96.74    74  16.306235
# No     Male       1919.75  302.00   263  15.731215
#        Female      977.68  149.77   140  15.318918
#                total_bill     tip  size    percent
# smoker sex
# Yes    Male       1337.07  183.07   150  13.691879
#        Female      593.27   96.74    74  16.306235
# No     Male       1919.75  302.00   263  15.731215
#        Female      977.68  149.77   140  15.318918

# %%
df5
# Out:
#                          total_bill    tip    percent
# smoker sex    day  size
# Yes    Male   Thur 1            NaN    NaN        NaN
#                    2         152.47  22.58  14.809471
#                    3          18.71   4.00  21.378942
#                    4          20.53   4.00  19.483682
#                    5            NaN    NaN        NaN
#                    6            NaN    NaN        NaN
#               Fri  1           8.58   1.92  22.377622
#                    2         114.87  15.28  13.301994
#                    3            NaN    NaN        NaN
#                    4          40.17   4.73  11.774956
#                    5            NaN    NaN        NaN
#                    6            NaN    NaN        NaN
#               Sat  1            NaN    NaN        NaN
#                    2         293.39  39.41  13.432632
#                    3         123.15  18.41  14.949249
#                    4         144.93  16.92  11.674602
# ...

# %%
df6=df5.dropna()
df6
# Out:
#                          total_bill    tip    percent
# smoker sex    day  size
# Yes    Male   Thur 2         152.47  22.58  14.809471
#                    3          18.71   4.00  21.378942
#                    4          20.53   4.00  19.483682
#               Fri  1           8.58   1.92  22.377622
#                    2         114.87  15.28  13.301994
#                    4          40.17   4.73  11.774956
#               Sat  2         293.39  39.41  13.432632
#                    3         123.15  18.41  14.949249
#                    4         144.93  16.92  11.674602
#                    5          28.15   3.00  10.657194
#               Sun  2         235.39  33.14  14.078763
#                    3          68.45   7.50  10.956903
#                    4          57.82  10.18  17.606365
#                    5          30.46   2.00   6.565988
#        Female Thur 2          74.95  12.70  16.944630
#                    3          16.47   3.23  19.611415
# ...

# %%
sb.countplot(x="day",data=df)

# %%
sb.countplot(x="day",hue='size',data=df)

# %%
sb.countplot(x="day",hue='smoker',data=df)

# %%
sb.countplot(x="day",hue='sex',data=df)

# %%
sb.countplot(x="sex",hue='day',data=df)
#sns.PairGrid(df)

# %%
sb.countplot(x="sex",hue='smoker',data=df)

# %%
df.replace({'sex':{'Male':0,'Female':1},'smoker':{'No':0,'Yes':1}},inplace=True)
df.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0  Sun  Dinner     2
# 1       10.34  1.66    0       0  Sun  Dinner     3
# 2       21.01  3.50    0       0  Sun  Dinner     3
# 3       23.68  3.31    0       0  Sun  Dinner     2
# 4       24.59  3.61    1       0  Sun  Dinner     4
#    total_bill   tip  sex  smoker  day    time  size
# 0       16.99  1.01    1       0  Sun  Dinner     2
# 1       10.34  1.66    0       0  Sun  Dinner     3
# 2       21.01  3.50    0       0  Sun  Dinner     3
# 3       23.68  3.31    0       0  Sun  Dinner     2
# 4       24.59  3.61    1       0  Sun  Dinner     4

# %%
days=pd.get_dummies(df['day'])
days.sample(5)
# Out:
#      Thur  Fri  Sat  Sun
# 121     1    0    0    0
# 163     0    0    0    1
# 181     0    0    0    1
# 210     0    0    1    0
# 97      0    1    0    0
#      Thur  Fri  Sat  Sun
# 121     1    0    0    0
# 163     0    0    0    1
# 181     0    0    0    1
# 210     0    0    1    0
# 97      0    1    0    0

# %%
days=pd.get_dummies(df['day'])
days.sample(5)
# Out:
#      Thur  Fri  Sat  Sun
# 229     0    0    1    0
# 235     0    0    1    0
# 239     0    0    1    0
# 216     0    0    1    0
# 194     1    0    0    0
#      Thur  Fri  Sat  Sun
# 229     0    0    1    0
# 235     0    0    1    0
# 239     0    0    1    0
# 216     0    0    1    0
# 194     1    0    0    0

# %%
days=pd.get_dummies(df['day'],drop_first=True)
days.sample(5)
# Out:
#      Fri  Sat  Sun
# 1      0    0    1
# 92     1    0    0
# 125    0    0    0
# 100    1    0    0
# 173    0    0    1
#      Fri  Sat  Sun
# 1      0    0    1
# 92     1    0    0
# 125    0    0    0
# 100    1    0    0
# 173    0    0    1

# %%
#days=pd.get_dummies(df['day'],drop_first=False)
#days.sample(5)

# %%
days=pd.get_dummies(df['day'],drop_first=True)
df=pd.concat([df,days],axis=1)
df.head()
# Out:
#    total_bill   tip  sex  smoker  day    time  size  Fri  Sat  Sun
# 0       16.99  1.01    1       0  Sun  Dinner     2    0    0    1
# 1       10.34  1.66    0       0  Sun  Dinner     3    0    0    1
# 2       21.01  3.50    0       0  Sun  Dinner     3    0    0    1
# 3       23.68  3.31    0       0  Sun  Dinner     2    0    0    1
# 4       24.59  3.61    1       0  Sun  Dinner     4    0    0    1
#    total_bill   tip  sex  smoker  day    time  size  Fri  Sat  Sun
# 0       16.99  1.01    1       0  Sun  Dinner     2    0    0    1
# 1       10.34  1.66    0       0  Sun  Dinner     3    0    0    1
# 2       21.01  3.50    0       0  Sun  Dinner     3    0    0    1
# 3       23.68  3.31    0       0  Sun  Dinner     2    0    0    1
# 4       24.59  3.61    1       0  Sun  Dinner     4    0    0    1

# %%
#times=pd.get_dummies(df['time'],drop_first=True)
#df=pd.concat([df,days],axis=1)
#df.sample(5)

# %%
#df.drop(['day','time'],inplace=True,axis=1)
#df.tail()

# %%
sb.catplot(x="day",y="total_bill",data=df)

# %%
sb.stripplot(x="day",y="total_bill",data=df)

# %%
sb.swarmplot(x="day",y="total_bill",data=df)

# %%
sb.catplot(x="day",y="total_bill",data=df)

# %%
# 25/11/2019

# %%
x=df[['total_bill','sex','smoker','size','Fri','Sat','Sun']]
y=df[['tip']]

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x
# Out:
#      total_bill  sex  smoker  size  Fri  Sat  Sun
# 0         16.99    1       0     2    0    0    1
# 1         10.34    0       0     3    0    0    1
# 2         21.01    0       0     3    0    0    1
# 3         23.68    0       0     2    0    0    1
# 4         24.59    1       0     4    0    0    1
# 5         25.29    0       0     4    0    0    1
# 6          8.77    0       0     2    0    0    1
# 7         26.88    0       0     4    0    0    1
# 8         15.04    0       0     2    0    0    1
# 9         14.78    0       0     2    0    0    1
# 10        10.27    0       0     2    0    0    1
# 11        35.26    1       0     4    0    0    1
# 12        15.42    0       0     2    0    0    1
# 13        18.43    0       0     4    0    0    1
# 14        14.83    1       0     2    0    0    1
# 15        21.58    0       0     2    0    0    1
# 16        10.33    1       0     3    0    0    1
# 17        16.29    0       0     3    0    0    1
# ...

# %%
X_test,X_train,y_test,y_train = train_test_split(x,y, test_size=0.3, random_state=26)

# %%
lr_mod= LinearRegression()
lr_mod.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predictions=lr_mod.predict(X_test)

# %%
predictions
# Out:
# array([[1.78101378],
#        [3.15945183],
#        [2.44232265],
#        [1.8928361 ],
#        [2.21783732],
#        [4.04336118],
#        [3.82792227],
#        [2.18711423],
#        [2.46687306],
#        [2.14659082],
#        [2.60249551],
#        [2.11763805],
#        [2.1318613 ],
#        [2.59763964],
#        [2.22072213],
#        [2.66168382],
#        [2.13217995],
#        [2.48209483],
#        [2.84615431],
#        [1.87490347],
#        [2.24460615],
#        [2.28033451],
#        [3.36594241],
#        [3.06135306],
#        [2.25593147],
#        [2.5986676 ],
#        [2.26942582],
#        [2.88371021],
#        [2.42949025],
#        [1.86911292],
#        [2.23159394],
#        [3.54418515],
#        [2.28164087],
#        [2.16572234],
#        [2.19052853],
#        [2.40634152],
#        [3.66205381],
#        [2.04945776],
#        [2.37696166],
#        [2.389373  ],
#        [1.94315975],
#        [2.13169337],
#        [2.47762694],
# ...

# %%
lr_mod.score(X_train,y_train)
# Out:
# 0.5383897888728473
# 0.5383897888728473

# %%
#y_test

# %%
sb.distplot(y_test-predictions)

# %%
myvals=np.array([100,1,1,6,0,0,0,]).reshape(1,-1)
lr_mod.predict(myvals)
# Out:
# array([[7.44233712]])
# array([[7.44233712]])

# %%
lr_mod.score(X_test,y_test)
# Out:
# 0.30154336926283265
# 0.30154336926283265

# %%
lr_mod.score(X_train,y_train)
# Out:
# 0.5383897888728473
# 0.5383897888728473

# %% [markdown]
# # error

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(y_test, predictions))

# %%
rms
# Out:
# 1.2401481547317976
# 1.2401481547317976
